# %%
import config as cf
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sqlalchemy
from sqlalchemy.orm import session
from sqlalchemy.ext.automap import automap_base

# %%
from sqlalchemy import create_engine
engine = create_engine(f'postgresql+psycopg2://postgres:{cf.password}@localhost:{cf.port}/employee')
conn = engine.connect()

# %%
# SQL code
#Select e.emp_no, s.salary
#From employees as e 
#Inner JOIN salaries as s
#ON e.emp_no = s.emp_no

# %%
#https://medium.com/analytics-vidhya/introduction-to-sql-using-python-using-join-statements-to-merge-multiple-tables-3b3513fe2c98

employee_df = pd.read_sql('SELECT e.emp_no, s.salary FROM employee as e INNER JOIN salaries as s ON e.emp_no = s.emp_no', conn)

# %%
employee_df.head(30)
# Out:
#     emp_no  salary
# 0    10001   60117
# 1    10005   78228
# 2    10010   72488
# 3    10011   42365
# 4    10013   40000
# 5    10017   71380
# 6    10018   55881
# 7    10019   44276
# 8    10026   47585
# 9    10035   41538
# 10   10037   40000
# 11   10043   49324
# 12   10045   41971
# 13   10051   48817
# 14   10055   80024
# 15   10058   52787
# 16   10060   74686
# 17   10061   68577
# 18   10072   40000
# 19   10078   47280
# 20   10081   55786
# 21   10085   40000
# 22   10091   40000
# 23   10096   61395
# 24   10104   45312
# 25   10117   52284
# 26   10126   40000
# 27   10127   40000
# 28   10138   53574
# 29   10147   40000

# %%
employee_df.describe()
# Out:
#               emp_no         salary
# count  300024.000000  300024.000000
# mean   253321.763392   52970.732451
# std    161828.235540   14301.478491
# min     10001.000000   40000.000000
# 25%     85006.750000   40000.000000
# 50%    249987.500000   48681.000000
# 75%    424993.250000   61758.000000
# max    499999.000000  129492.000000

# %%
# Create a histogram to visualize the most common salary ranges for employees.
plt.hist(employee_df['salary'], bins=8)
plt.xlabel('Salary ($)')
plt.ylabel('Salary Range for employees')
plt.show()

# %%
salary_df = pd.read_sql('SELECT e.emp_no, e.emp_title_id, s.salary FROM employee as e INNER JOIN salaries as s ON e.emp_no = s.emp_no', conn)

# %%
salary_df.head()
# Out:
#    emp_no emp_title_id  salary
# 0   10005        s0001   78228
# 1   10010        e0002   72488
# 2   10011        s0001   42365
# 3   10018        e0003   55881
# 4   10035        e0003   41538

# %%
titles_df = pd.read_sql_query('Select * from titles', conn)

# %%
titles_df.head()
# Out:
#   emp_title_id               title
# 0        s0001               Staff
# 1        s0002        Senior Staff
# 2        e0001  Assistant Engineer
# 3        e0002            Engineer
# 4        e0003     Senior Engineer

# %%
Merge_df = pd.merge(titles_df,salary_df, on= "emp_title_id", how = "outer")
Merge_df.head()
# Out:
#   emp_title_id  title  emp_no  salary
# 0        s0001  Staff   10005   78228
# 1        s0001  Staff   10011   42365
# 2        s0001  Staff   10126   40000
# 3        s0001  Staff   10176   54635
# 4        s0001  Staff   10178   50568

# %%
Bar_df = Merge_df[['title','salary']]
Bar_final_df = Bar_df.groupby(['title']).mean()
Bar_final_df
# Out:
#                           salary
# title
# Assistant Engineer  48564.434447
# Engineer            48535.336511
# Manager             51531.041667
# Senior Engineer     48506.799871
# Senior Staff        58550.172704
# Staff               58465.382850
# Technique Leader    48582.896092

# %%
# SQL code
#Select e.emp_title_id, s.salary, t.emp_title_id, avg(s.salary) as avg_salary
#From employees as e 
#Inner JOIN salaries as s
#ON e.emp_no = s.emp_no
#INNER JOIN titles as t
#ON e.emp_title_id = t.emp_title_id
#GROUP BY s.salary
#Order by avg_salary desc;

# %%
# Create a bar chart of average salary by title.
Bar_final_df.plot(kind="bar", color = ['purple'], figsize=(10,5))
plt.title('Average Salary by Title', size = 20)
plt.xlabel('Titles', size = '18')
plt.ylabel('Average Salary ($)', size = '18')
plt.show()
plt.tight_layout()

# %% [markdown]
# ## Epilogue

# %%
#Search for the ID number 499942 use the same code from my query.sql

employee_search = pd.read_sql('select e.emp_no, e.last_name, e.first_name FROM employee as e WHERE e.emp_no = 499942', conn)

employee_search.head()
# Out:
#    emp_no last_name first_name
# 0  499942  Foolsday      April
